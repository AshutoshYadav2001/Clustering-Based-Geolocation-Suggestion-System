# %% [markdown]
# ## Introduction/Business Problem:
# In the fast moving, effort-intense environment that a student inhabits,It’s a frequent occurrence that one is too tired to fix oneself a home-cooked meal. And of course, even if one gets home-cooked meals every day, it is not unusual to want to go out for a good meal every once in a while for social/recreational purposes. Either way, it’s a commonly understood idea that regardless of where one lives, the food one eats is an important aspect of the lifestyle one leads.
#
# Now, imagine a scenario where a person has newly moved into a new location. They already have certain preferences, certain tastes. It would save both the student and the food providers a lot of hassle if the student lived close to their preferred outlets. Convenience means better sales, and saved time for the customer.
#
# Food delivery apps aside, managers of restaurant chains and hotels can also leverage this information. For example, if a manager of a restaurant already knows the demographic of his current customers, they’d ideally want to open at a location where this demographic is at its highest concentration, ensuring short commute times to the location and more customers served.If potential hotel locations are being evaluated, a site that caters to a wide variety of tastes would be ideal, since one would want every guest to have something to their liking.
#
# Essentially, the problem statement is this:
#
# “How can one identify trends in an individual’s* daily routine and leverage them?”
#
# *Here, a student

# %% [markdown]
# Let us first import all the packages we need for analysis.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
import geopandas as gpd
import matplotlib.cm as cm
import folium
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image
from IPython.core.display import HTML
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
print("All packages imported!")
# Out:
# All packages imported!

# %% [markdown]
# Alright, now let us import the raw dataset for student preferences...

# %%
dfstudents=pd.read_csv('food_coded.csv')

# %% [markdown]
# We shall only take the columns useful to us:

# %%
dfclean=dfstudents[['cook','eating_out','employment','ethnic_food','exercise','fruit_day','income','on_off_campus','pay_meal_out','sports','veggies_day']]
dfclean.dropna(axis=0,inplace=True)
dfclean.head()
# Out:
# C:\Users\yadav\AppData\Local\Temp\ipykernel_7016\1683749749.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfclean.dropna(axis=0,inplace=True)
#    cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0   2.0           3         3.0            1       1.0          5     5.0
# 1   3.0           2         2.0            4       1.0          4     4.0
# 2   1.0           2         3.0            5       2.0          5     6.0
# 3   2.0           2         3.0            5       3.0          4     6.0
# 4   1.0           2         2.0            4       1.0          4     6.0
#
#    on_off_campus  pay_meal_out  sports  veggies_day
# 0            1.0             2     1.0            5
# 1            1.0             4     1.0            4
# 2            2.0             3     2.0            5
# 3            1.0             2     2.0            3
# 4            1.0             4     1.0            4

# %% [markdown]
# ## Identifying the different kinds of students

# %% [markdown]
# Let us visualise the distrubtion of data with a boxplot:

# %%
plt.figure(figsize=(20, 10))
#plt.xticks(rotation='vertical')
sns.boxplot

ax = sns.boxplot(data = dfclean)
ax.tick_params(labelsize=20)
plt.xticks(rotation=45, ha='right')

plt.show()
# Out:
# C:\Users\yadav\anaconda3\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %%
# set number of clusters
kclusters = 3

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(dfclean)
dfclean['Cluster']=kmeans.labels_
# Out:
# C:\Users\yadav\AppData\Local\Temp\ipykernel_7016\2834361600.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfclean['Cluster']=kmeans.labels_

# %%
fig, axes = plt.subplots(1,kclusters, figsize=(20, 10), sharey=True)
axes[0].set_ylabel('Coded Values', fontsize=25)

for k in range(kclusters):
    plt.sca(axes[k])
    plt.xticks(rotation=45,ha='right')
    sns.boxplot(data = dfclean[dfclean['Cluster'] == k].drop('Cluster',1), ax=axes[k])

plt.show()
# Out:
# C:\Users\yadav\AppData\Local\Temp\ipykernel_7016\1103199276.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   sns.boxplot(data = dfclean[dfclean['Cluster'] == k].drop('Cluster',1), ax=axes[k])
# C:\Users\yadav\anaconda3\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# C:\Users\yadav\AppData\Local\Temp\ipykernel_7016\1103199276.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   sns.boxplot(data = dfclean[dfclean['Cluster'] == k].drop('Cluster',1), ax=axes[k])
# C:\Users\yadav\anaconda3\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# C:\Users\yadav\AppData\Local\Temp\ipykernel_7016\1103199276.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   sns.boxplot(data = dfclean[dfclean['Cluster'] == k].drop('Cluster',1), ax=axes[k])
# C:\Users\yadav\anaconda3\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %% [markdown]
# **Possible insights:**
#
# Kmeans:
# 2 clusters: No clear demarcation is seen; we can’t discriminate on 2 categories alone.
# 3 clusters: Now we see three clear groups: One high income group which insists on eating healthy, the other is more relaxed in diet.
#
# The low income group has its own profile, as discussed in insights.
#
# For higher numbers of clusters, it becomes difficult to draw any concrete conclusions.
#
# High income students in general are:
#
# 1.>Much more likely to stay on campus.
# 2.>Less likely to cook.
# 3.>Eat out more often.
#
# In addition, a subset of higher income students: 1.>Eat out less often.
#
# 2.>Have a healthier, more varied diet in general. (Eat ethnic food, fruits, vegetables etc.)
#
# Lower income students are more likely to:
#
# 1.>Eat more vegetables
# 2.>Eat more fruits.
# 3.>More likely to cook, so more likely to stay off campus.
# 4.>Obviously, pay less for meals out.

# %% [markdown]
# Essentially, we need to think about accomodation for 2 types of students, low income and high income(varied diet).
#
# The high income(fixed diet) students will ideally stay on campus, so they don't have to be taken into account.

# %% [markdown]
# # Finding the students a home

# %% [markdown]
# Our analysis will be on the city I currently reside in, i.e Dehradun, India!
#
# Specifically, I will begin by looking at the hostel areas around my college.
#
# We begin by defining the parameters of our foursquare search query:

# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize

url = "https://api.foursquare.com/v3/places/nearby?ll=30.4195%2C77.9668&query=hostel%2C%20PG&limit=50&intent=browse&radius=5"
#url = "https://api.foursquare.com/v3/places/nearby?ll=30.4172%2C77.9676&query=Hostel%2C%20PG&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3bwgrZ8jL2HXYqHqSAsg5REy1ti8FL7rFKjyCKovI3TQ="
}

# Now, we pull the results of the query into a json file.
response = requests.get(url, headers=headers)
data = response.json()
places = data['results']
# transform results into a dataframe
dataframe = json_normalize(places)
dataframe
#print(dataframe)
# Out:
# C:\Users\yadav\AppData\Local\Temp\ipykernel_7016\3234469001.py:18: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   dataframe = json_normalize(places)
#                       fsq_id  \
# 0   5107eaa1e4b050e334e81401
# 1   508e328ae4b01ff75366ce6f
# 2   50ff6375e4b09ee9fe32943a
# 3   5110f2cae4b042d4c3d18280
# 4   531646a111d208cb45c83e5f
# 5   5171b2d5e4b0b410ca634500
# 6   5cde686ec0c0840025194d98
# 7   53122c8e498e023b2634f3f5
# 8   5114b948e4b030cc20d255c8
# 9   51b9e032498e165e6f1c4418
# 10  4dc79139fa76d685ce1465f7
# 11  4e56879452b12ddfc1e256a7
# 12  50020dfde4b0d51a41340f4d
# 13  6327455f11a36b2ce3f9450a
# 14  4d4ff4cc9d4937041727bc39
# 15  500c20ade4b0629c8bd90583
# 16  526a338411d22aac6f2ec5ec
# 17  52d18030498e1638128d0859
# 18  4ead4cdc722eefae84601937
# 19  4ead4c6493ad7677a8f3169b
#
#                                            categories chains   closed_bucket  \
# 0   [{'id': 12079, 'name': 'Housing Development', ...     []      LikelyOpen
# 1   [{'id': 12035, 'name': 'College Residence Hall...     []  VeryLikelyOpen
# 2   [{'id': 13065, 'name': 'Restaurant', 'short_na...     []      LikelyOpen
# 3   [{'id': 13002, 'name': 'Bakery', 'short_name':...     []      LikelyOpen
# 4   [{'id': 12035, 'name': 'College Residence Hall...     []  VeryLikelyOpen
# 5   [{'id': 12094, 'name': 'Residential Building',...     []  VeryLikelyOpen
# 6   [{'id': 19013, 'name': 'Hostel', 'short_name':...     []  VeryLikelyOpen
# 7   [{'id': 15004, 'name': 'Assisted Living Servic...     []  VeryLikelyOpen
# 8   [{'id': 15004, 'name': 'Assisted Living Servic...     []  VeryLikelyOpen
# 9   [{'id': 15004, 'name': 'Assisted Living Servic...     []  VeryLikelyOpen
# 10  [{'id': 19013, 'name': 'Hostel', 'short_name':...     []      LikelyOpen
# 11  [{'id': 12014, 'name': 'College Academic Build...     []  VeryLikelyOpen
# 12  [{'id': 19013, 'name': 'Hostel', 'short_name':...     []      LikelyOpen
# 13  [{'id': 19013, 'name': 'Hostel', 'short_name':...     []      LikelyOpen
# 14                                                 []     []  VeryLikelyOpen
# 15  [{'id': 19013, 'name': 'Hostel', 'short_name':...     []      LikelyOpen
# 16  [{'id': 12035, 'name': 'College Residence Hall...     []  VeryLikelyOpen
# 17  [{'id': 12035, 'name': 'College Residence Hall...     []  VeryLikelyOpen
# 18  [{'id': 12035, 'name': 'College Residence Hall...     []  VeryLikelyOpen
# 19  [{'id': 12035, 'name': 'College Residence Hall...     []  VeryLikelyOpen
#
#     distance                                 link  \
# 0        352  /v3/places/5107eaa1e4b050e334e81401
# 1        371  /v3/places/508e328ae4b01ff75366ce6f
# 2        456  /v3/places/50ff6375e4b09ee9fe32943a
# 3        456  /v3/places/5110f2cae4b042d4c3d18280
# 4        448  /v3/places/531646a111d208cb45c83e5f
# 5        866  /v3/places/5171b2d5e4b0b410ca634500
# 6       1243  /v3/places/5cde686ec0c0840025194d98
# 7       2120  /v3/places/53122c8e498e023b2634f3f5
# 8       3661  /v3/places/5114b948e4b030cc20d255c8
# 9       9943  /v3/places/51b9e032498e165e6f1c4418
# 10      9202  /v3/places/4dc79139fa76d685ce1465f7
# 11     12598  /v3/places/4e56879452b12ddfc1e256a7
# 12     11135  /v3/places/50020dfde4b0d51a41340f4d
# 13     10745  /v3/places/6327455f11a36b2ce3f9450a
# 14     13247  /v3/places/4d4ff4cc9d4937041727bc39
# 15     14547  /v3/places/500c20ade4b0629c8bd90583
# 16     18454  /v3/places/526a338411d22aac6f2ec5ec
# 17     22990  /v3/places/52d18030498e1638128d0859
# 18     31363  /v3/places/4ead4cdc722eefae84601937
# 19     31622  /v3/places/4ead4c6493ad7677a8f3169b
#
#                                      name      timezone  \
# 0                        upes hostel C102  Asia/Kolkata
# 1                          College Hostel  Asia/Kolkata
# 2                        Upes hostel mess  Asia/Kolkata
# 3                   UPES hostel Tuck shop  Asia/Kolkata
# 4                Upes Campus Hostel A 316  Asia/Kolkata
# 5                            V.I.P Hostel  Asia/Kolkata
# 6                           Zenith Hostel  Asia/Kolkata
# 7                       red bricks Hostel  Asia/Kolkata
# 8             Beside Doon Scholars Hostel  Asia/Kolkata
# 9                        Friends girls PG  Asia/Kolkata
# 10                  Hill View Boys Hostel  Asia/Kolkata
# 11             Doon pg college Govindgarh  Asia/Kolkata
# 12                           Youth Hostel  Asia/Kolkata
# 13                     The Hosteller Mini  Asia/Kolkata
# 14                         Clifton Hostel  Asia/Kolkata
# 15                Officers Transit Hostel  Asia/Kolkata
# 16  Shivalik Boys Hostel, Doon University  Asia/Kolkata
# 17        Mata Gujri Hostel SBSPGI Campus  Asia/Kolkata
# 18                            Boys Hostel  Asia/Kolkata
# 19         Boys Hostel, HIMS, Jolly Grant  Asia/Kolkata
#
#     geocodes.main.latitude  geocodes.main.longitude location.country  \
# 0                30.416690                77.968376               IN
# 1                30.416951                77.969096               IN
# 2                30.415450                77.967975               IN
# 3                30.415450                77.967975               IN
# 4                30.415593                77.968202               IN
# 5                30.412926                77.971582               IN
# 6                30.408437                77.965573               IN
# 7                30.400415                77.967765               IN
# 8                30.386521                77.968685               IN
# 9                30.332705                77.992241               IN
# 10               30.337426                77.953987               IN
# 11               30.322633                78.034856               IN
# 12               30.444996                78.079192               IN
# 13               30.458912                78.069223               IN
# 14               30.454920                78.098924               IN
# 15               30.306411                78.043049               IN
# 16               30.267607                78.044854               IN
# 17               30.252482                78.108009               IN
# 18               30.195718                78.165830               IN
# 19               30.194362                78.168115               IN
#
#                location.cross_street  \
# 0
# 1
# 2
# 3
# 4
# 5   Near New Taste Of India Bidholii
# 6
# 7
# 8
# 9                       Near Jk Bank
# 10
# 11
# 12
# 13
# 14                           Landour
# 15
# 16
# 17
# 18                       Jolly Grant
# 19                       Jolly Grant
#
#                            location.formatted_address  \
# 0
# 1                         Upes, Dehradun, Uttarakhand
# 2
# 3                                              941735
# 4
# 5   Vip Hostel (Near New Taste Of India Bidholii),...
# 6                                 248197, Uttarakhand
# 7
# 8
# 9       Subash (Near Jk Bank), Jammu, Jammu & Kashmir
# 10           Kehri Gaon, Dehradun 248007, Uttarakhand
# 11
# 12  Mussoorie Dehradun Road, Mussoorie 248122, Utt...
# 13                      Mussoorie 248179, Uttaranchal
# 14  Woodstock School (Landour), Mussoorie 248179, ...
# 15  41 Race Course Road, Govind Nagar, Race Course...
# 16
# 17
# 18                Hims (Jolly Grant), Dehradun 195678
# 19                       Hims (Jolly Grant), Dehradun
#
#                                   location.address location.locality  \
# 0                                              NaN               NaN
# 1                                             Upes          Dehradun
# 2                                              NaN               NaN
# 3                                              NaN               NaN
# 4                                              NaN               NaN
# 5                                       Vip Hostel          Dehradun
# 6                                              NaN               NaN
# 7                                              NaN               NaN
# 8                                              NaN               NaN
# 9                                           Subash             Jammu
# 10                                      Kehri Gaon          Dehradun
# 11                                             NaN               NaN
# 12                         Mussoorie Dehradun Road         Mussoorie
# 13                                             NaN         Mussoorie
# 14                                Woodstock School         Mussoorie
# 15  41 Race Course Road, Govind Nagar, Race Course          Dehradun
# 16                                             NaN               NaN
# 17                                             NaN               NaN
# 18                                            Hims          Dehradun
# 19                                            Hims          Dehradun
#
#     location.region location.postcode  \
# 0               NaN               NaN
# 1       Uttarakhand               NaN
# 2               NaN               NaN
# 3               NaN            941735
# 4               NaN               NaN
# 5               NaN            634500
# 6       Uttarakhand            248197
# 7               NaN               NaN
# 8               NaN               NaN
# 9   Jammu & Kashmir               NaN
# 10      Uttarakhand            248007
# 11              NaN               NaN
# 12      Uttaranchal            248122
# 13      Uttaranchal            248179
# 14      Uttarakhand            248179
# 15      Uttarakhand            248001
# 16              NaN               NaN
# 17              NaN               NaN
# 18              NaN            195678
# 19              NaN               NaN
#
#                             location.address_extended  geocodes.roof.latitude  \
# 0                                                 NaN                     NaN
# 1                                                 NaN                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
# 4                                                 NaN                     NaN
# 5                                                 NaN                     NaN
# 6                                                 NaN                     NaN
# 7                                                 NaN                     NaN
# 8                                                 NaN                     NaN
# 9                                                 NaN                     NaN
# 10  Near Law College, Chakarata Road, Prem Nagar, ...                     NaN
# 11                                                NaN                     NaN
# 12                                Near Mussoorie Lake                     NaN
# 13                                                NaN                     NaN
# 14                                                NaN                     NaN
# 15                                                NaN               30.306411
# 16                                                NaN               30.267607
# 17                                                NaN                     NaN
# 18                                                NaN               30.195718
# 19                                                NaN               30.194362
#
#     geocodes.roof.longitude
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                78.043049
# 16                78.044854
# 17                      NaN
# 18                78.165830
# 19                78.168115

# %% [markdown]
# Some categories don't mean much to us, such as ID and referralID. Let's only take the fields relevant to us:

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['geocodes.main.latitude', 'geocodes.main.longitude','fsq_id','distance']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']

    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
#dataframe_filtered.drop([4,17,18,21,24,30,43],axis=0,inplace=True) #remove some unwanted locations like hotels
dataframe_filtered.drop(['country','region','locality'],axis=1,inplace=True) #no need for those columns as we know we're in Bangalore,IN
dataframe_filtered
# Out:
#                                      name                 categories  \
# 0                        upes hostel C102        Housing Development
# 1                          College Hostel     College Residence Hall
# 2                        Upes hostel mess                 Restaurant
# 3                   UPES hostel Tuck shop                     Bakery
# 4                Upes Campus Hostel A 316     College Residence Hall
# 5                            V.I.P Hostel       Residential Building
# 6                           Zenith Hostel                     Hostel
# 7                       red bricks Hostel    Assisted Living Service
# 8             Beside Doon Scholars Hostel    Assisted Living Service
# 9                        Friends girls PG    Assisted Living Service
# 10                  Hill View Boys Hostel                     Hostel
# 11             Doon pg college Govindgarh  College Academic Building
# 12                           Youth Hostel                     Hostel
# 13                     The Hosteller Mini                     Hostel
# 14                         Clifton Hostel                       None
# 15                Officers Transit Hostel                     Hostel
# 16  Shivalik Boys Hostel, Doon University     College Residence Hall
# 17        Mata Gujri Hostel SBSPGI Campus     College Residence Hall
# 18                            Boys Hostel     College Residence Hall
# 19         Boys Hostel, HIMS, Jolly Grant     College Residence Hall
#
#                         cross_street  \
# 0
# 1
# 2
# 3
# 4
# 5   Near New Taste Of India Bidholii
# 6
# 7
# 8
# 9                       Near Jk Bank
# 10
# 11
# 12
# 13
# 14                           Landour
# 15
# 16
# 17
# 18                       Jolly Grant
# 19                       Jolly Grant
#
#                                     formatted_address  \
# 0
# 1                         Upes, Dehradun, Uttarakhand
# 2
# 3                                              941735
# 4
# 5   Vip Hostel (Near New Taste Of India Bidholii),...
# 6                                 248197, Uttarakhand
# 7
# 8
# 9       Subash (Near Jk Bank), Jammu, Jammu & Kashmir
# 10           Kehri Gaon, Dehradun 248007, Uttarakhand
# 11
# 12  Mussoorie Dehradun Road, Mussoorie 248122, Utt...
# 13                      Mussoorie 248179, Uttaranchal
# 14  Woodstock School (Landour), Mussoorie 248179, ...
# 15  41 Race Course Road, Govind Nagar, Race Course...
# 16
# 17
# 18                Hims (Jolly Grant), Dehradun 195678
# 19                       Hims (Jolly Grant), Dehradun
#
#                                            address postcode  \
# 0                                              NaN      NaN
# 1                                             Upes      NaN
# 2                                              NaN      NaN
# 3                                              NaN   941735
# 4                                              NaN      NaN
# 5                                       Vip Hostel   634500
# 6                                              NaN   248197
# 7                                              NaN      NaN
# 8                                              NaN      NaN
# 9                                           Subash      NaN
# 10                                      Kehri Gaon   248007
# 11                                             NaN      NaN
# 12                         Mussoorie Dehradun Road   248122
# 13                                             NaN   248179
# 14                                Woodstock School   248179
# 15  41 Race Course Road, Govind Nagar, Race Course   248001
# 16                                             NaN      NaN
# 17                                             NaN      NaN
# 18                                            Hims   195678
# 19                                            Hims      NaN
#
#                                      address_extended   latitude  longitude  \
# 0                                                 NaN  30.416690  77.968376
# 1                                                 NaN  30.416951  77.969096
# 2                                                 NaN  30.415450  77.967975
# 3                                                 NaN  30.415450  77.967975
# 4                                                 NaN  30.415593  77.968202
# 5                                                 NaN  30.412926  77.971582
# 6                                                 NaN  30.408437  77.965573
# 7                                                 NaN  30.400415  77.967765
# 8                                                 NaN  30.386521  77.968685
# 9                                                 NaN  30.332705  77.992241
# 10  Near Law College, Chakarata Road, Prem Nagar, ...  30.337426  77.953987
# 11                                                NaN  30.322633  78.034856
# 12                                Near Mussoorie Lake  30.444996  78.079192
# 13                                                NaN  30.458912  78.069223
# 14                                                NaN  30.454920  78.098924
# 15                                                NaN  30.306411  78.043049
# 16                                                NaN  30.267607  78.044854
# 17                                                NaN  30.252482  78.108009
# 18                                                NaN  30.195718  78.165830
# 19                                                NaN  30.194362  78.168115
#
#                       fsq_id  distance
# 0   5107eaa1e4b050e334e81401       352
# 1   508e328ae4b01ff75366ce6f       371
# 2   50ff6375e4b09ee9fe32943a       456
# 3   5110f2cae4b042d4c3d18280       456
# 4   531646a111d208cb45c83e5f       448
# 5   5171b2d5e4b0b410ca634500       866
# 6   5cde686ec0c0840025194d98      1243
# 7   53122c8e498e023b2634f3f5      2120
# 8   5114b948e4b030cc20d255c8      3661
# 9   51b9e032498e165e6f1c4418      9943
# 10  4dc79139fa76d685ce1465f7      9202
# 11  4e56879452b12ddfc1e256a7     12598
# 12  50020dfde4b0d51a41340f4d     11135
# 13  6327455f11a36b2ce3f9450a     10745
# 14  4d4ff4cc9d4937041727bc39     13247
# 15  500c20ade4b0629c8bd90583     14547
# 16  526a338411d22aac6f2ec5ec     18454
# 17  52d18030498e1638128d0859     22990
# 18  4ead4cdc722eefae84601937     31363
# 19  4ead4c6493ad7677a8f3169b     31622

# %%
#import folium

# Define coordinates of the college
map_bang = folium.Map(location=[30.4195, 77.9668], zoom_start=12)

# Instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

# Extract latitude, longitude, and labels from the JSON response
latitude = []
longitude = []
labels = []

for place in data['results']:
    lat = place['geocodes']['main']['latitude']
    lng = place['geocodes']['main']['longitude']
    name = place['name']
    latitude.append(lat)
    longitude.append(lng)
    labels.append(name)

# Iterate through the data and add markers to the map
for lat, lng, label in zip(latitude, longitude, labels):
    folium.Marker([lat, lng], popup=label).add_to(locations)

# Add the markers to the map
map_bang.add_child(locations)

# Display the map
map_bang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a551451bd76b99ec5a04017a5a12ca37 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a551451bd76b99ec5a04017a5a12ca37&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a551451bd76b99ec5a04017a5a12ca37 = L.map(
#                 &quot;map_a551451bd76b99ec5a04017a5a12ca37&quot;,
#                 {
#                     center: [30.4195, 77.9668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff1e1ef7f0c120c810a4182efad695c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a551451bd76b99ec5a04017a5a12ca37);
#
#
#             var feature_group_e1c8fe810bf1445ebd94c77d41d7283b = L.featureGroup(
#                 {}
#             ).addTo(map_a551451bd76b99ec5a04017a5a12ca37);
#
#
#             var marker_5cba617c91be2dfe6c6de1d90ae928ae = L.marker(
#                 [30.41669, 77.968376],
#                 {}
#             ).addTo(feature_group_e1c8fe810bf1445ebd94c77d41d7283b);
#
#
#         var popup_7182988323eaecd40d37e5d1b6d337c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa6b1fc4c9e747af29ddd837e1bd5126 = $(`&lt;div id=&quot;html_aa6b1fc4c9e747af29ddd837e1bd5126&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;upes hostel C102&lt;/div&gt;`)[0];
#                 popup_7182988323eaecd40d37e5d1b6d337c7.setContent(html_aa6b1fc4c9e747af29ddd837e1bd5126);
#
#
#
#         marker_5cba617c91be2dfe6c6de1d90ae928ae.bindPopup(popup_7182988323eaecd40d37e5d1b6d337c7)
#         ;
#
#
#
#
#             var marker_d8282aee79d5be7e9a6eb3d57a334a7f = L.marker(
#                 [30.416951, 77.969096],
#                 {}
#             ).addTo(feature_group_e1c8fe810bf1445ebd94c77d41d7283b);
#
#
#         var popup_3e5e139762d51c6cbdafa8eb934d3bc5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1435836ecfe53d878d3b23d06d5d2c11 = $(`&lt;div id=&quot;html_1435836ecfe53d878d3b23d06d5d2c11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;College Hostel&lt;/div&gt;`)[0];
#                 popup_3e5e139762d51c6cbdafa8eb934d3bc5.setContent(html_1435836ecfe53d878d3b23d06d5d2c11);
#
#
#
#         marker_d8282aee79d5be7e9a6eb3d57a334a7f.bindPopup(popup_3e5e139762d51c6cbdafa8eb934d3bc5)
#         ;
#
#
#
#
#             var marker_c51cae31b0e813671a648b6cadc35653 = L.marker(
#                 [30.41545, 77.967975],
#                 {}
#             ).addTo(feature_group_e1c8fe810bf1445ebd94c77d41d7283b);
#
#
#         var popup_7ba13044e7bbdf65ec243f765617e2b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d208878b40238c033473ba9d2304483c = $(`&lt;div id=&quot;html_d208878b40238c033473ba9d2304483c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Upes hostel mess&lt;/div&gt;`)[0];
#                 popup_7ba13044e7bbdf65ec243f765617e2b8.setContent(html_d208878b40238c033473ba9d2304483c);
#
#
#
#         marker_c51cae31b0e813671a648b6cadc35653.bindPopup(popup_7ba13044e7bbdf65ec243f765617e2b8)
#         ;
#
#
#
#
#             var marker_b97188326654c3a722aa52645236f291 = L.marker(
#                 [30.41545, 77.967975],
#                 {}
#             ).addTo(feature_group_e1c8fe810bf1445ebd94c77d41d7283b);
#
#
#         var popup_c6cbdc1990ac4eb5ffb4528d180224e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a5bd3c420c84910ec08fa75b124f5855 = $(`&lt;div id=&quot;html_a5bd3c420c84910ec08fa75b124f5855&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UPES hostel Tuck shop&lt;/div&gt;`)[0];
#                 popup_c6cbdc1990ac4eb5ffb4528d180224e1.setContent(html_a5bd3c420c84910ec08fa75b124f5855);
#
#
#
#         marker_b97188326654c3a722aa52645236f291.bindPopup(popup_c6cbdc1990ac4eb5ffb4528d180224e1)
#         ;
#
#
#
#
#             var marker_26fe148a2f7a724f7001abe751f094aa = L.marker(
#                 [30.415593, 77.968202],
#                 {}
#             ).addTo(feature_group_e1c8fe810bf1445ebd94c77d41d7283b);
#
#
#         var popup_7784eb0e1dc710b0ba439135056ebdb1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b4a5e21abe0bc6ee23057838bf99ef88 = $(`&lt;div id=&quot;html_b4a5e21abe0bc6ee23057838bf99ef88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Upes Campus Hostel A 316&lt;/div&gt;`)[0];
#                 popup_7784eb0e1dc710b0ba439135056ebdb1.setContent(html_b4a5e21abe0bc6ee23057838bf99ef88);
#
#
#
#         ma

# %% [markdown]
# Now, let's figure out which locations are ideal for which kinds of student.
#
# We will keep in mind the fact that the lower income students need a steady supply of fresh fruits, while the high income students need plenty of restaurant options to choose from.
